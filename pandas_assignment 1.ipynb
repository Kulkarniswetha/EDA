# %%
import pandas as pd

# %%
data=pd.read_csv("/content/Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# EXLORAING DATASET:

# %%
#what is the structure of the dataset ? Display the frist 5 rows and identify
# the column names,datatypes,and the number of missing values(if any)

# %% [markdown]
# 1.what is the structure of the dataset ? Display the frist 5 rows and identify
#  the column names,datatypes,and the number of missing values(if any).

# %%
#structure of dataset
structure=data.shape
print("The structure of the dataset is:",structure)
# Out:
# The structure of the dataset is: (150, 6)

# %%
#first 5 rows
first_5_rows=data.head()
print("The first 5 rows of the dataset are:\n",first_5_rows)
# Out:
# The first 5 rows of the dataset are:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#column names
col=data.columns
print("The column names are:",col)
# Out:
# The column names are: Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#data types
data_types=data.dtypes
print("The data types of the columns are:\n",data_types)
# Out:
# The data types of the columns are:
#  Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
#missing values
missing_values=data.isnull().sum()
print("The number of missing values in each column are:\n",missing_values)
# Out:
# The number of missing values in each column are:
#  Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# **SUMMARY STATISTICS**

# %% [markdown]
# 2.what are the mean,median,minimum ,maximum values for each numeric column in the dataset?

# %%
summary_stats=data.describe()
print("The summary statistics for the numeric columns are:\n",summary_stats)
# Out:
# The summary statistics for the numeric columns are:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# **SPECIES DISTRIBUTION**

# %% [markdown]
# 3.How many samples belong to each species in the dataset?create a count of each species.

# %%
species_counts=data['Species'].value_counts()
print("The count of each species in the dataset are:\n",species_counts)
# Out:
# The count of each species in the dataset are:
#  Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **FEATURE RELATIONSHIPS**

# %% [markdown]
# 4.what is the average sepal length for each species? similarly,what is the average petal width for each species?

# %%
avg_sepal_length=data["SepalLengthCm"].mean()
print("The average sepal length for each species is:",avg_sepal_length)
# Out:
# The average sepal length for each species is: 5.843333333333334

# %%
avg_petal_width=data["PetalWidthCm"].mean()
print("The average petal width for each species is:",avg_petal_width)
# Out:
# The average petal width for each species is: 1.1986666666666668

# %% [markdown]
# **FILTERING DATA**

# %% [markdown]
# 5.Create a subset of the dataset containing only the samples where the petal length is greater than 1.5.How many such samples exist,and which species do they belong to?

# %%
subset=data[data["PetalLengthCm"]>1.5]
print("The subset of the dataset containing only the samples where the petal length is greater than 1.5 is:\n",subset)
# Out:
# The subset of the dataset containing only the samples where the petal length is greater than 1.5 is:
#        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 5      6            5.4           3.9            1.7           0.4
# 11    12            4.8           3.4            1.6           0.2
# 18    19            5.7           3.8            1.7           0.3
# 20    21            5.4           3.4            1.7           0.2
# 23    24            5.1           3.3            1.7           0.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 5       Iris-setosa
# ...

# %%
#number of samples in the subset
num_samples=len(subset)
print("The number of samples in the subset is:",num_samples)
# Out:
# The number of samples in the subset is: 113

# %%
#species counts in the subset
species_counts=subset["Species"].value_counts()
print("The species counts in the subset are:\n",species_counts)
# Out:
# The species counts in the subset are:
#  Species
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        13
# Name: count, dtype: int64
