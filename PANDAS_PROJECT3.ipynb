# %% [markdown]
# # **PANDAS_PROJECT 3**

# %% [markdown]
# import require libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading & Exploring data

# %%
df1=pd.read_csv("/content/amsterdam_weekdays.csv")

# %%
df2=pd.read_csv("/content/amsterdam_weekends.csv")

# %%
df3=pd.read_csv("/content/athens_weekdays.csv")

# %%
df4=pd.read_csv("/content/athens_weekends.csv")

# %%
df5=pd.read_csv("/content/barcelona_weekdays.csv")

# %%
df6=pd.read_csv("/content/barcelona_weekends.csv")

# %%
df7=pd.read_csv("/content/berlin_weekdays.csv")

# %%
df8=pd.read_csv("/content/berlin_weekends.csv")

# %%
df9=pd.read_csv("/content/budapest_weekdays.csv")

# %%
df10=pd.read_csv("/content/budapest_weekends.csv")

# %%
df11=pd.read_csv("/content/lisbon_weekdays.csv")

# %%
df12=pd.read_csv("/content/lisbon_weekends.csv")

# %%
df13=pd.read_csv("/content/london_weekdays.csv")

# %%
df14=pd.read_csv("/content/london_weekends.csv")

# %%
df15=pd.read_csv("/content/paris_weekdays.csv")

# %%
df16=pd.read_csv("/content/paris_weekends.csv")

# %%
df17=pd.read_csv("/content/rome_weekdays.csv")

# %%
df18=pd.read_csv("/content/rome_weekends.csv")

# %%
df19=pd.read_csv("/content/vienna_weekdays.csv")

# %%
df20=pd.read_csv("/content/vienna_weekends.csv")

# %%
df1["city"]="Amsterdam"
df3["city"]="Athens"
df5["city"]="Berlin"
df7["city"]="Budapest"
df9["city"]="Barcelona"
df11["city"]="Lisbon"
df13["city"]="London"
df15["city"]="Paris"
df17["city"]="Rome"
df19["city"]="Vienna"
df2["city"]="Amsterdam"
df4["city"]="Athens"
df6["city"]="Berlin"
df8["city"]="Budapest"
df10["city"]="Barcelona"
df12["city"]="Lisbon"
df14["city"]="London"
df16["city"]="Paris"
df18["city"]="Rome"
df20["city"]="Vienna"

# %%
#Concatenate files into two master datasets: one for weekdays and one for weekends.
weekdays=pd.concat([df1,df3,df5,df7,df9,df11,df13,df15,df17,df19],ignore_index=True)
weekdays.head(5)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
weekends=pd.concat([df2,df4,df6,df8,df10,df12,df14,df16,df18,df20],ignore_index=True)
weekends.head(5)
# Out:
#    Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0           0   319.640053     Private room        False          True
# 1           1   347.995219     Private room        False          True
# 2           2   482.975183     Private room        False          True
# 3           3   485.552926     Private room        False          True
# 4           4  2771.541724  Entire home/apt        False         False
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      0    1                 9.0  ...
# 1              2.0              False      0    1                 9.0  ...
# 2              4.0              False      0    1                 9.0  ...
# 3              2.0               True      0    0                10.0  ...
# 4              4.0               True      0    0                10.0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
 #Combine the datasets into a single unified dataset with an additional column indicating "day_type" as either 'weekday' or 'weekend'.
weekends["data_type"]="weekend"
weekdays["data_type"]="weekdays"

# %%
combined_data=pd.concat([weekdays,weekends],ignore_index=True)
combined_data.head(5)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
print(combined_data.isnull().sum())
# Out:
# Unnamed: 0                    0
# realSum                       0
# room_type                     0
# room_shared                   0
# room_private                  0
# person_capacity               0
# host_is_superhost             0
# multi                         0
# biz                           0
# cleanliness_rating            0
# guest_satisfaction_overall    0
# bedrooms                      0
# dist                          0
# metro_dist                    0
# attr_index                    0
# attr_index_norm               0
# rest_index                    0
# rest_index_norm               0
# lng                           0
# lat                           0
# city                          0
# data_type                     0
# dtype: int64

# %%
# Handle duplicates if present
combined_data.duplicated().sum()
# Out:
# 0

# %%
combined_data.dtypes
# Out:
# Unnamed: 0                      int64
# realSum                       float64
# room_type                      object
# room_shared                      bool
# room_private                     bool
# person_capacity               float64
# host_is_superhost                bool
# multi                           int64
# biz                             int64
# cleanliness_rating            float64
# guest_satisfaction_overall    float64
# bedrooms                        int64
# dist                          float64
# metro_dist                    float64
# attr_index                    float64
# attr_index_norm               float64
# rest_index                    float64
# rest_index_norm               float64
# lng                           float64
# lat                           float64
# city                           object
# data_type                      object
# dtype: object

# %%
combined_data.shape
# Out:
# (51707, 22)

# %% [markdown]
# Ensure correct data types for columns (e.g., numerical columns, categorical columns).
#
# **The categorical columns are**
#
# 1.room_type: the type of the accommodation
#
# 2.room_shared: dummy variable for shared rooms
#
# 3.room_private: dummy variable for private rooms
#
# 4.host_is_superhost: dummy variable for superhost status and data_type

# %% [markdown]
# **The numerical columns are**
#
# 1.realSum: the full price of accommodation for two people and two nights in EUR.
#
# 2.person_capacity: the maximum number of guests.
#
# 3.multi: dummy variable if the listing belongs to hosts with 2-4 offers.
#
# 4.biz: dummy variable if the listing belongs to hosts with more than 4 offers.
#
# 5.cleanliness_rating: cleanliness rating
#
# 6.guest_satisfaction_overall: overall rating of the listing.
#
# 7.bedrooms: number of bedrooms (0 for studios)
#
# 8.dist: distance from city centre in km
#
# 9.metro_dist: distance from nearest metro station in km
#
# 10.attr_index: attraction index of the listing location
#
# 11.attr_index_norm: normalised attraction index (0-100)
#
# 12.rest_index: restaurant index of the listing location
#
# 13.rest_index_norm: normalised restaurant index (0-100)
#
# 14.lng: longitude of the listing location
#
# 15.lat: latitude of the listing location

# %%
#Address any outliers in key features such as realSum (price) and guest_satisfaction_overall.

# %%
important_columns = ['realSum', 'person_capacity', 'guest_satisfaction_overall', 'bedrooms']
combined_data[important_columns].plot(kind='box', subplots=True, layout=(2, 2), figsize=(12, 8))

plt.show()

# %% [markdown]
# # Exploratory Analysis-Univariate Analysis

# %%
#Price Distribution: Plot histograms and boxplots of realSum to understand price distributions for weekdays and weekends separately.
sns.histplot(data=combined_data, hue='data_type', x='realSum',kde=True,bins=20)
# Out:
# <Axes: xlabel='realSum', ylabel='Count'>

# %%
sns.barplot(data=combined_data, x='data_type', y='realSum')
# Out:
# <Axes: xlabel='data_type', ylabel='realSum'>

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='room_type', data=combined_data)
plt.title('Room Type Counts')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(combined_data['guest_satisfaction_overall'], bins=20)
plt.title('Guest Satisfaction Distribution')
plt.xlabel('Guest Satisfaction Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
#Price vs. Room Type: Compare average prices for different room_type categories between weekdays and weekends using bar plots.
sns.barplot(data=combined_data, x='room_type', y='realSum', hue='data_type')
# Out:
# <Axes: xlabel='room_type', ylabel='realSum'>

# %%
#Superhost Status: Analyze how host_is_superhost impacts average prices and guest satisfaction ratings using boxplots or violin plots.
sns.boxplot(data=combined_data, x='host_is_superhost', y='realSum')
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='realSum'>

# %%
sns.boxplot(data=combined_data, x='host_is_superhost', y='guest_satisfaction_overall')
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='guest_satisfaction_overall'>

# %%
# Distance Impact: Plot realSum against dist and metro_dist to understand how distance from city center and metro stations affects pricing.

plt.figure(figsize=(10, 6))
sns.scatterplot(x='dist', y='realSum', data=combined_data)
plt.title('Price vs. Distance from City Center')
plt.xlabel('Distance from City Center (dist)')
plt.ylabel('Price (realSum)')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='metro_dist', y='realSum', data=combined_data)
plt.title('Price vs. Distance from Metro Station')
plt.xlabel('Distance from Metro Station (metro_dist)')
plt.ylabel('Price (realSum)')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
correlation=combined_data[['realSum','cleanliness_rating','guest_satisfaction_overall','person_capacity','bedrooms','dist','metro_dist','attr_index','attr_index_norm','rest_index','rest_index_norm','lng','lat']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm',fmt="0.2f")
# Out:
# <Axes: >

# %%
#Feature Interactions: Explore how combinations of features (e.g., multi and biz) influence price and satisfaction.
sns.barplot(data=combined_data, x='multi', y='realSum', hue='biz')
# Out:
# <Axes: xlabel='multi', ylabel='realSum'>

# %%
sns.barplot(data=combined_data, x='multi', y='guest_satisfaction_overall', hue='biz')
# Out:
# <Axes: xlabel='multi', ylabel='guest_satisfaction_overall'>

# %% [markdown]
# # City-Specific Analysis

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='city', y='realSum', data=combined_data)
plt.title('Average Price by City')
plt.xlabel('City')
plt.ylabel('Average Price')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#Room type according to the different cities
plt.figure(figsize=(12, 6))
sns.countplot(x='city', hue='room_type', data=combined_data)
plt.title('Room Type Distribution by City')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Room Type')
plt.show()

# %%
#Guest satisfaction according to the different cities
plt.figure(figsize=(12, 6))
sns.barplot(x='city', y='guest_satisfaction_overall', data=combined_data, ci=95, capsize=0.2)
plt.title('Average Guest Satisfaction by City')
plt.xlabel('City')
plt.ylabel('Average Guest Satisfaction')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-58-a0e4cb96de44>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.barplot(x='city', y='guest_satisfaction_overall', data=combined_data, ci=95, capsize=0.2)

# %% [markdown]
# # Weekday vs. Weekend Analysis

# %%
combined_data.groupby(["city","data_type"])["realSum"].mean()
# Out:
# city       data_type
# Amsterdam  weekdays     545.020526
#            weekend      604.828018
# Athens     weekdays     155.866982
#            weekend      147.580456
# Barcelona  weekdays     168.429367
#            weekend      185.120628
# Berlin     weekdays     288.391667
#            weekend      300.277940
# Budapest   weekdays     240.220422
#            weekend      249.252516
# Lisbon     weekdays     236.345459
#            weekend      240.044051
# London     weekdays     360.230348
#            weekend      364.389747
# Paris      weekdays     398.786678
#            weekend      387.028589
# Rome       weekdays     201.618053
#            weekend      209.130063
# Vienna     weekdays     240.384834
#            weekend      242.739524
# Name: realSum, dtype: float64

# %%
combined_data.groupby(["city","data_type"])["realSum"].median()
# Out:
# city       data_type
# Amsterdam  weekdays     430.248635
#            weekend      491.645771
# Athens     weekdays     127.715417
#            weekend      127.715417
# Barcelona  weekdays     147.459698
#            weekend      160.031959
# Berlin     weekdays     208.532129
#            weekend      204.691973
# Budapest   weekdays     187.786295
#            weekend      192.460503
# Lisbon     weekdays     223.030019
#            weekend      227.720450
# London     weekdays     256.355982
#            weekend      268.115431
# Paris      weekdays     318.529220
#            weekend      316.199087
# Rome       weekdays     179.786314
#            weekend      184.462161
# Vienna     weekdays     204.520487
#            weekend      212.000093
# Name: realSum, dtype: float64

# %%
# Room Availability: Explore how room capacity (person_capacity) changes across day types
sns.countplot(data=combined_data, x='person_capacity', hue='data_type')
# Out:
# <Axes: xlabel='person_capacity', ylabel='count'>

# %%
satisfaction_scores = combined_data.groupby(['city', 'data_type'])['guest_satisfaction_overall'].agg(['mean', 'std'])
print(satisfaction_scores)
# Out:
#                           mean        std
# city      data_type
# Amsterdam weekdays   94.362647   6.089691
#           weekend    94.685773   6.632364
# Athens    weekdays   95.100264   8.271262
#           weekend    94.905976   8.426506
# Barcelona weekdays   94.527001   6.531566
#           weekend    94.647331   6.520511
# Berlin    weekdays   90.929260   8.695707
#           weekend    91.327856   8.496424
# Budapest  weekdays   94.299065   6.912388
#           weekend    94.350000   6.700242
# Lisbon    weekdays   91.047602   9.151417
#           weekend    91.139367   9.146213
# London    weekdays   90.324447  11.755838
#           weekend    90.921175  11.289857
# Paris     weekdays   91.851438   8.996678
#           weekend    92.201237   8.656113
# Rome      weekdays   93.200134   7.750982
#           weekend    93.045204   7.878205
# Vienna    weekdays   93.797468   7.096291
#           weekend    93.667037   7.340501

# %%
satisfaction_scores = satisfaction_scores.reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='city', y='mean', hue='data_type', data=satisfaction_scores)
plt.title('Average Guest Satisfaction by City (Weekdays vs. Weekends)')
plt.xlabel('City')
plt.ylabel('Average Guest Satisfaction')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Data Type')
plt.show()

# %%
combined_data.groupby(["data_type"])["guest_satisfaction_overall"].mean()
# Out:
# data_type
# weekdays    92.586549
# weekend     92.668791
# Name: guest_satisfaction_overall, dtype: float64

# %% [markdown]
# # Insights and Recommendaions

# %% [markdown]
# **For Hosts:**
#
#  *Pricing: Adjust prices for city, day (weekends higher), room type, and location.
#
# *Guest Satisfaction: Cleanliness, amenities, quick responses, Superhost status.
#
# **For Guests:**
#
# *Lower Prices: Weekday travel, less popular cities, flexibility.
#
# *Higher Satisfaction: Superhosts, reviews, desired amenities/location.
